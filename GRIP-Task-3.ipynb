# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('./SampleSuperstore.csv')
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State
# 0    Second Class   Consumer  United States        Henderson    Kentucky  \
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity
# 0        42420  South        Furniture    Bookcases  261.9600         2  \
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.shape
# Out:
# (9994, 13)

# %%
#Distinct entries in particular coloumns
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#Checking the missing values
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#Checking the duplicated data
df.duplicated().sum()
# Out:
# 17

# %%
#Dropping duplicate data
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State
# 0       Second Class   Consumer  United States        Henderson    Kentucky  \
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity
# 0           42420  South        Furniture    Bookcases  261.9600         2  \
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9977 rows x 13 columns]

# %%
#Distinct entries in particular coloumns after dropping duplocates
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
#Dropping unwanted rows from dataset
df=df.drop(['Postal Code'],axis=1)
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State
# 0    Second Class   Consumer  United States        Henderson    Kentucky  \
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
# Select only the numeric columns
numeric_df = df.select_dtypes(include=[np.number])

# %%
# Calculate the correlation matrix
corr = numeric_df.corr()
# Plot the correlation heatmap
plt.figure(figsize=(10, 5))
sns.heatmap(corr, annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
df_state=df['State'].value_counts()
df_state
# Out:
# State
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# Louisiana                 42
# South Carolina            42
# Nevada                    39
# Nebraska                  38
# New Mexico                37
# Iowa                      30
# New Hampshire             27
# Kansas                    24
# Idaho                     21
# Montana                   15
# South Dakota              12
# Vermont                   11
# District of Columbia      10
# Maine                      8
# North Dakota               7
# West Virginia              4
# Wyoming                    1
# Name: count, dtype: int64

# %%
df_state.plot(kind='bar',figsize=(15,5),color='green')
plt.ylabel('Frequency / Number of deals')
plt.xlabel('States')
plt.title('Bar Representation of State Wise Dealings', fontsize = 20)
plt.show()

# %%
df_state.mean()
# Out:
# 203.9591836734694

# %%
#Statewise analysis of Profit, Discount and Sales
df_state1=df.groupby(['State'])[['Sales', 'Discount', 'Profit']].mean()
df_state1.head()
# Out:
#                  Sales  Discount     Profit
# State
# Alabama     319.846557  0.000000  94.865989
# Arizona     157.508933  0.303571 -15.303235
# Arkansas    194.635500  0.000000  66.811452
# California  228.729451  0.072764  38.171608
# Colorado    176.418231  0.316484 -35.867351

# %%
#Statewise Profit Analysis
df_state2=df_state1.sort_values('Profit')
df_state2[['Profit']].plot(kind = 'bar', figsize = (15,4),color='green')
plt.title('State wise Profit Analysis', fontsize = 20)
plt.ylabel('Profit per State')
plt.xlabel('States')
plt.show()

# %%
df_state1[['Sales']].plot(kind = 'bar', figsize = (15,4),color='red')
plt.title('State wise Sales Analysis', fontsize = 20)
plt.ylabel('Sales per State')
plt.xlabel('States')
plt.show()

# %%
df_state1[['Discount']].plot(kind = 'bar', figsize = (15,4),color='red')
plt.title('State wise Discount Analysis', fontsize = 20)
plt.ylabel('Discount per State')
plt.xlabel('States')
plt.show()

# %%
df_city=df['City'].value_counts()
df_city_head=df_city.head(50)
df_city_head
# Out:
# City
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Houston          377
# Chicago          314
# Columbus         222
# San Diego        170
# Springfield      163
# Dallas           157
# Jacksonville     125
# Detroit          115
# Newark            95
# Richmond          90
# Jackson           82
# Columbia          81
# Aurora            68
# Phoenix           63
# Long Beach        61
# Arlington         60
# San Antonio       59
# Miami             57
# Louisville        57
# Rochester         53
# Charlotte         52
# Henderson         51
# Lakewood          49
# Lancaster         46
# Fairfield         45
# Milwaukee         45
# Denver            44
# Lawrence          44
# Baltimore         43
# Cleveland         42
# Pasadena          42
# San Jose          42
# Fayetteville      41
# Salem             40
# Atlanta           39
# Austin            39
# Franklin          37
# Tampa             36
# Wilmington        36
# Huntsville        36
# Decatur           35
# Toledo            32
# Tucson            32
# Providence        31
# Lafayette         31
# Name: count, dtype: int64

# %%
df_city_head.plot(kind='bar',figsize=(15,5),color='purple')
plt.ylabel('Frequency / Number of deals')
plt.xlabel('City')
plt.title('Bar representation of City Wise Dealings', fontsize = 20)
plt.show()

# %%
df_city_head.mean()
# Out:
# 132.32

# %%
#City wise analysis of Profit, Discount and Sales
df_city1=df.groupby(['City'])[['Sales', 'Discount', 'Profit']].mean()
df_city1.head()
# Out:
#                   Sales  Discount     Profit
# City
# Aberdeen      25.500000  0.000000   6.630000
# Abilene        1.392000  0.800000  -3.758400
# Akron        129.999333  0.357143  -8.887410
# Albuquerque  158.582857  0.057143  45.292007
# Alexandria   344.973125  0.000000  19.913644

# %%
#Citywise Profit Analysis
df_city2=df_city1.sort_values('Profit')
df_city2_head=df_city2.head(30)
df_city2_head[['Profit']].plot(kind = 'bar', figsize = (15,4),color='purple')
plt.title('City wise Profit Analysis', fontsize = 20)
plt.ylabel('Profit per City')
plt.xlabel('Cities')
plt.show()

# %%
df_city2_tail=df_city2.tail(30)
df_city2_tail[['Profit']].plot(kind = 'bar', figsize = (15,4),color='purple')
plt.title('City wise Profit Analysis', fontsize = 20)
plt.ylabel('Profit per City')
plt.xlabel('Cities')
plt.show()

# %%
df_city_sales=df_city1.sort_values('Sales')
df_city_sales.head(50)[['Sales']].plot(kind = 'bar', figsize = (15,4),color='purple')
plt.title('City wise Sales Analysis', fontsize = 20)
plt.ylabel('Sales per City')
plt.xlabel('Cities')
plt.show()

# %%
df_city_dis=df_city1.sort_values('Discount')
df_city_dis.tail(50)[['Discount']].plot(kind = 'bar', figsize = (15,4),color='green')
plt.title('City wise Discount Analysis', fontsize = 20)
plt.ylabel('Discount per City')
plt.xlabel('Cities')
plt.show()

# %%
df_ship=df['Ship Mode'].value_counts()
df_ship
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
df_ship.plot(kind='pie',figsize=[8,8],autopct='%1.1f%%',colors = ['pink', 'purple', 'green', 'orange'])
plt.title('Shipping mode wise distribution of orders')
# Out:
# Text(0.5, 1.0, 'Shipping mode wise distribution of orders')

# %%
df_shipmode = df.groupby(['Ship Mode'])[['Sales', 'Profit']].mean()
df_shipmode
# Out:
#                      Sales     Profit
# Ship Mode
# First Class     228.497024  31.839948
# Same Day        236.396179  29.266591
# Second Class    236.089239  29.535545
# Standard Class  227.583067  27.494770

# %%
df_shipmode.plot.pie(subplots=True,
                     figsize=(18, 20), 
                     autopct='%1.1f%%', 
                     labels = df_shipmode.index,colors = ['pink', 'purple', 'green', 'orange'])
# Out:
# array([<Axes: ylabel='Sales'>, <Axes: ylabel='Profit'>], dtype=object)

# %%
df_sub=df['Sub-Category'].value_counts()
df_sub
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
df_sub.plot(kind='pie',figsize=[8,8],autopct='%1.1f%%')
plt.title('Sub-category wise distribution of orders')
# Out:
# Text(0.5, 1.0, 'Sub-category wise distribution of orders')

# %%
df_sub_sum=df.groupby("Sub-Category").sum()
df_sub_sum
# Out:
#                                                       Ship Mode
# Sub-Category
# Accessories   Second ClassFirst ClassStandard ClassFirst Cla...  \
# Appliances    Standard ClassStandard ClassStandard ClassFirs...
# Art           Standard ClassSecond ClassStandard ClassStanda...
# Binders       Standard ClassStandard ClassStandard ClassSeco...
# Bookcases     Second ClassStandard ClassStandard ClassFirst ...
# Chairs        Second ClassSecond ClassStandard ClassStandard...
# Copiers       Second ClassSecond ClassStandard ClassStandard...
# Envelopes     Standard ClassStandard ClassStandard ClassSeco...
# Fasteners     Standard ClassSecond ClassFirst ClassStandard ...
# Furnishings   Standard ClassStandard ClassFirst ClassStandar...
# Labels        Second ClassStandard ClassStandard ClassStanda...
# Machines      Standard ClassStandard ClassFirst ClassSecond ...
# Paper         Standard ClassSecond ClassFirst ClassFirst Cla...
# Phones        Standard ClassStandard ClassSecond ClassFirst ...
# Storage       Standard ClassStandard ClassSecond ClassStanda...
# Supplies      Standard ClassSecond ClassSecond ClassSame Day...
# Tables        Standard ClassStandard ClassStandard ClassStan...
#
#                                                         Segment
# Sub-Category
# Accessories   ConsumerCorporateConsumerConsumerConsumerConsu...  \
# Appliances    ConsumerHome OfficeCorporateCorporateCorporate...
# Art           ConsumerConsumerCorporateConsumerConsumerConsu...
# Binders       ConsumerConsumerHome OfficeConsumerConsumerCon...
# Bookcases     ConsumerConsumerHome OfficeHome OfficeHome Off...
# Chairs        ConsumerConsumerHome OfficeConsumerConsumerHom...
# Copiers       ConsumerConsumerConsumerHome OfficeConsumerCor...
# Envelopes     ConsumerHome OfficeCorporateConsumerConsumerCo...
# Fasteners     CorporateConsumerCorporateConsumerConsumerCons...
# Furnishings   ConsumerConsumerCorporateConsumerConsumerConsu...
# Labels        CorporateConsumerConsumerConsumerCorporateCorp...
# Machines      ConsumerCorporateConsumerCorporateCorporateHom...
# Paper         ConsumerHome OfficeConsumerConsumerConsumerCon...
# Phones        ConsumerConsumerConsumerCorporateHome OfficeCo...
# Storage       ConsumerConsumerConsumerCorporateCorporateCons...
# Supplies      ConsumerConsumerCorporateCorporateHome OfficeH...
# Tables        ConsumerConsumerConsumerConsumerConsumerConsum...
#
#                                                         Country
# Sub-Category
# Accessories   United StatesUnited StatesUnited StatesUnited ...  \
# Appliances    United StatesUnited StatesUnited StatesUnited ...
# Art           United StatesUnited StatesUnited StatesUnited ...
# Binders       United StatesUnited StatesUnited StatesUnited ...
# Bookcases     United StatesUnited StatesUnited StatesUnited ...
# Chairs        United StatesUnited StatesUnited StatesUnited ...
# Copiers       United StatesUnited StatesUnited StatesUnited ...
# Envelopes     United StatesUnited StatesUnited StatesUnited ...
# Fasteners     United StatesUnited StatesUnited StatesUnited ...
# Furnishings   United StatesUnited StatesUnited StatesUnited ...
# Labels        United StatesUnited StatesUnited StatesUnited ...
# Machines      United StatesUnited StatesUnited StatesUnited ...
# Paper         United StatesUnited StatesUnited StatesUnited ...
# Phones        United StatesUnited StatesUnited StatesUnited ...
# Storage       United StatesUnited StatesUnited StatesUnited ...
# Supplies      United StatesUnited StatesUnited StatesUnited ...
# Tables        United StatesUnited StatesUnited StatesUnited ...
#
#                                                            City
# Sub-Category
# Accessories   Los AngelesEaganDoverTroyLos AngelesRochesterC...  \
# Appliances    Los AngelesFort WorthFremontDecaturSaint PaulI...
# Art           Los AngelesSan FranciscoFremontPhiladelphiaPhi...
# Binders       Los AngelesSeattleFort WorthSan FranciscoLos A...
# Bookcases     HendersonPhiladelphiaHoustonNew York CityNew Y...
# Chairs        HendersonPhiladelphiaHoustonNew AlbanyTroyChic...
# Copiers       Los AngelesDes MoinesSan FranciscoGreat FallsS...
# Envelopes     PhiladelphiaHoustonDurhamColumbusColumbusWilmi...
# Fasteners     New York CityColumbusColumbusRosevilleSaginawD...
# Furnishings   Los AngelesPhiladelphiaRichardsonNew AlbanyLos...
# Labels        Los AngelesNew AlbanyRochesterEdmondChicagoMed...
# Machines      San AntonioMedinaDublinHoustonHoustonNew York ...
# Paper         ConcordHoustonTroyTroyLos AngelesSpringfieldJa...
# Phones        Los AngelesLos AngelesSan FranciscoRichardsonH...
# Storage       Fort LauderdaleMadisonWest JordanLos AngelesMe...
# Supplies      RosevilleNewarkTamaracManchesterJacksonPhoenix...
# Tables        Fort LauderdaleLos AngelesOremSeattleBloomingt...
#
#                                                           State
# Sub-Category
# Accessories   CaliforniaMinnesotaDelawareNew YorkCaliforniaM...  \
# Appliances    CaliforniaTexasNebraskaAlabamaMinnesotaMissour...
# Art           CaliforniaCaliforniaNebraskaPennsylvaniaPennsy...
# Binders       CaliforniaWashingtonTexasCaliforniaCaliforniaP...
# Bookcases     KentuckyPennsylvaniaTexasNew YorkNew YorkOhioO...
# Chairs        KentuckyPennsylvaniaTexasIndianaNew YorkIllino...
# Copiers       CaliforniaWashingtonCaliforniaMontanaCaliforni...
# Envelopes     PennsylvaniaTexasNorth CarolinaOhioOhioDelawar...
# Fasteners     New YorkOhioOhioCaliforniaMichiganOhioNew Jers...
# Furnishings   CaliforniaPennsylvaniaTexasIndianaCaliforniaTe...
# Labels        CaliforniaIndianaMinnesotaOklahomaIllinoisOhio...
# Machines      TexasOhioOhioTexasTexasNew YorkPennsylvaniaNew...
# Paper         North CarolinaTexasNew YorkNew YorkCaliforniaV...
# Phones        CaliforniaCaliforniaCaliforniaTexasTexasIllino...
# Storage       FloridaWisconsinUtahCaliforniaFloridaMichiganN...
# Supplies      CaliforniaOhioFloridaConnecticutMichiganArizon...
# Tables        FloridaCaliforniaUtahWashingtonIllinoisColorad...
#
#                                                          Region
# Sub-Category
# Accessories   WestCentralEastEastWestCentralCentralWestSouth...  \
# Appliances    WestCentralCentralSouthCentralCentralWestCentr...
# Art           WestWestCentralEastEastEastWestWestWestSouthCe...
# Binders       WestWestCentralWestWestEastEastCentralCentralE...
# Bookcases     SouthEastCentralEastEastEastEastEastEastCentra...
# Chairs        SouthEastCentralCentralEastCentralSouthSouthCe...
# Copiers       WestWestWestWestWestWestCentralEastEastWestEas...
# Envelopes     EastCentralSouthEastEastEastWestWestWestEastEa...
# Fasteners     EastEastEastWestCentralEastEastEastWestWestWes...
# Furnishings   WestEastCentralCentralWestSouthCentralCentralC...
# Labels        WestCentralCentralCentralCentralEastEastEastWe...
# Machines      CentralEastEastCentralCentralEastEastEastCentr...
# Paper         SouthCentralEastEastWestSouthCentralWestCentra...
# Phones        WestWestWestCentralCentralCentralEastEastWestW...
# Storage       SouthCentralWestWestSouthCentralEastSouthCentr...
# Supplies      WestEastSouthEastCentralWestEastCentralWestWes...
# Tables        SouthWestWestWestCentralWestCentralSouthSouthC...
#
#                                                        Category        Sales
# Sub-Category
# Accessories   TechnologyTechnologyTechnologyTechnologyTechno...  167380.3180  \
# Appliances    Office SuppliesOffice SuppliesOffice SuppliesO...  107532.1610
# Art           Office SuppliesOffice SuppliesOffice SuppliesO...   27118.7920
# Binders       Office SuppliesOffice SuppliesOffice SuppliesO...  203412.7330
# Bookcases     FurnitureFurnitureFurnitureFurnitureFurnitureF...  114879.9963
# Chairs        FurnitureFurnitureFurnitureFurnitureFurnitureF...  328449.1030
# Copiers       TechnologyTechnologyTechnologyTechnologyTechno...  149528.0300
# Envelopes     Office SuppliesOffice SuppliesOffice SuppliesO...   16476.4020
# Fasteners     Office SuppliesOffice SuppliesOffice SuppliesO...    3024.2800
# Furnishings   FurnitureFurnitureFurnitureFurnitureFurnitureF...   91705.1640
# Labels        Office SuppliesOffice SuppliesOffice SuppliesO...   12486.3120
# Machines      TechnologyTechnologyTechnologyTechnologyTechno...  189238.6310
# Paper         Office SuppliesOffice SuppliesOffice SuppliesO...   78479.2060
# Phones        TechnologyTechnologyTechnologyTechnologyTechno...  330007.0540
# Storage       Office SuppliesOffice SuppliesOffice SuppliesO...  223843.6080
# Supplies      Office SuppliesOffice SuppliesOffice SuppliesO...   46673.5380
# Tables        FurnitureFurnitureFurnitureFurnitureFurnitureF...  206965.5320
#
#               Quantity  Discount      Profit
# Sub-Category
# Accessories       2976     60.80  41936.6357
# Appliances        1729     77.60  18138.0054
# Art               3000     59.60   6527.7870
# Binders           5974    567.00  30221.7633
# Bookcases          868     48.14  -3472.5560
# Chairs            2356    105.00  26590.1663
# Copiers            234     11.00  55617.8249
# Envelopes          906     20.40   6964.1767
# Fasteners          914     17.80    949.5182
# Furnishings       3563    132.40  13059.1436
# Labels            1400     25.00   5546.2540
# Machines           440     35.20   3384.7569
# Paper             5178    102.60  34053.5693
# Phones            3289    137.40  44515.7306
# Storage           3158     63.20  21278.8264
# Supplies           647     14.60  -1189.0995
# Tables            1241     83.35 -17725.4811

# %%
df_sub_sum[['Sales', 'Profit']].plot(kind = 'bar', figsize = [20,8])
plt.ylabel('Total Sales/Profits',fontsize = 12)
# Out:
# Text(0, 0.5, 'Total Sales/Profits')

# %%
#Discount v/s Profit
plt.figure(figsize=(12,5))
sns.lineplot(x='Discount',y='Profit',data=df,color='green')
plt.title("Discount V/S Profit")
# Out:
# Text(0.5, 1.0, 'Discount V/S Profit')

# %%
#Discount v/s Sales
plt.figure(figsize=(12,5))
sns.lineplot(x='Discount',y='Sales',data=df,color='green')
plt.title("Discount V/S Sales")
# Out:
# Text(0.5, 1.0, 'Discount V/S Sales')
